# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaVardhan1027/AI-Crop-Predictor/blob/main/Final_Draft_CROP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/model1 (1).csv'

try:
    df = pd.read_csv(file_path)
    print(df)
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.EmptyDataError:
    print(f"Error: The CSV file at {file_path} is empty.")
except pd.errors.ParserError:
    print(f"Error: There was a problem parsing the CSV file at {file_path}. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                    District_Name       Season     Area  Production   Crop
# 0       NORTH AND MIDDLE ANDAMAN  Rabi           294.5        90.8    Tur
# 1                 SOUTH ANDAMANS  Rabi            20.5        13.2    Tur
# 2                      ANANTAPUR  Kharif       21400.0      2600.0    Tur
# 3                      ANANTAPUR  Kharif       27400.0      9100.0    Tur
# 4                      ANANTAPUR  Kharif       30693.0      7888.0    Tur
# ...                          ...          ...      ...         ...    ...
# 124964                   PURULIA  Rabi          2013.0      5152.0  Wheat
# 124965                   PURULIA  Rabi          1880.0      4206.0  Wheat
# 124966                   PURULIA  Rabi          1648.0      3310.0  Wheat
# 124967                   PURULIA  Rabi          1187.0      2675.0  Wheat
# ...

# %%
print(df['Season'].unique())
# Out:
# ['Rabi       ' 'Kharif     ' 'Winter     ' 'Whole Year ' 'Autumn     '
#  'Summer     ']

# %%
df['Season'] = df['Season'].replace({'summer': 'kharif', 'winter': 'rabi', 'autumn': 'rabi'})

try:
    df.to_csv(file_path, index=False)  # index=False prevents writing row indices
    print(f"Successfully saved the modified DataFrame to {file_path}")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")

print(df['Season'].unique())
# Out:
# Successfully saved the modified DataFrame to /content/drive/My Drive/model1 (1).csv
# ['Rabi       ' 'Kharif     ' 'Winter     ' 'Whole Year ' 'Autumn     '
#  'Summer     ']

# %%
print(df['Season'].unique())
# Out:
# ['Rabi       ' 'Kharif     ' 'Winter     ' 'Whole Year ' 'Autumn     '
#  'Summer     ']

# %%
import pandas as pd
from google.colab import drive


drive.mount('/content/drive')

file_path = '/content/drive/My Drive/model1 (1).csv'

try:
    df = pd.read_csv(file_path)
    print(df)
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.EmptyDataError:
    print(f"Error: The CSV file at {file_path} is empty.")
except pd.errors.ParserError:
    print(f"Error: There was a problem parsing the CSV file at {file_path}. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")


print(df['Season'].unique())


df['Season'] = df['Season'].replace({'summer': 'kharif', 'winter': 'rabi', 'autumn': 'rabi'})

print(df['Season'].unique())

try:
    df.to_csv(file_path, index=False)  # index=False prevents writing row indices
    print(f"Successfully saved the modified DataFrame to {file_path}")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")

print(df['Season'].unique())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                    District_Name       Season     Area  Production   Crop
# 0       NORTH AND MIDDLE ANDAMAN  Rabi           294.5        90.8    Tur
# 1                 SOUTH ANDAMANS  Rabi            20.5        13.2    Tur
# 2                      ANANTAPUR  Kharif       21400.0      2600.0    Tur
# 3                      ANANTAPUR  Kharif       27400.0      9100.0    Tur
# 4                      ANANTAPUR  Kharif       30693.0      7888.0    Tur
# ...                          ...          ...      ...         ...    ...
# 124964                   PURULIA  Rabi          2013.0      5152.0  Wheat
# 124965                   PURULIA  Rabi          1880.0      4206.0  Wheat
# 124966                   PURULIA  Rabi          1648.0      3310.0  Wheat
# 124967                   PURULIA  Rabi          1187.0      2675.0  Wheat
# ...

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/model1 (1).csv'

try:
    df = pd.read_csv(file_path)
    print(df['Crop'].unique())
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.EmptyDataError:
    print(f"Error: The CSV file at {file_path} is empty.")
except pd.errors.ParserError:
    print(f"Error: There was a problem parsing the CSV file at {file_path}. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Tur' 'Bajra' 'Coconut ' 'Cotton(lint)' 'Groundnut' 'Jowar' 'Maize'
#  'Moong(Green Gram)' 'Niger seed' 'Paddy' 'Ragi' 'Rice' 'Sesamum'
#  'Soyabean' 'Sugarcane' 'Sunflower' 'Urad' 'Wheat']

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/Crop_recommendation.csv'

try:
    df = pd.read_csv(file_path)
    print(df['label'].unique())
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.EmptyDataError:
    print(f"Error: The CSV file at {file_path} is empty.")
except pd.errors.ParserError:
    print(f"Error: There was a problem parsing the CSV file at {file_path}. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/model1 (1).csv'
try:
    df = pd.read_csv(file_path)
    df['Season'] = df['Season'].str.strip().str.capitalize()
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    exit()
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
    exit()

def predict_crop(N, P, K, pH, season, district_name):
    """Predicts the optimal crop based on user input and dataset values."""
    try:
        N, P, K, pH = float(N), float(P), float(K), float(pH)
    except ValueError:
        return "Invalid input: N, P, K, and pH must be numbers."


    season_mapping = {
        "kharif": "Kharif",
        "rabi": "Rabi"
    }
    season = season_mapping.get(season.lower(), "Invalid")

    if season == "Invalid":
        return "Invalid season."


    df['District_Name'] = df['District_Name'].str.strip()

    if district_name.strip() not in df['District_Name'].unique():
        return "Invalid district name."


    filtered_df = df[
        (df['Season'] == season) &
        (df['District_Name'] == district_name.strip())
    ]

    if filtered_df.empty:
        return "No matching crops found for the given criteria."

    predicted_crop = filtered_df['Crop'].mode().iloc[0]  # Most frequent crop
    return predicted_crop


N = input("Enter Nitrogen (N) value: ")
P = input("Enter Phosphorus (P) value: ")
K = input("Enter Potassium (K) value: ")
pH = input("Enter pH value: ")
season = input("Enter Season (kharif, rabi): ")
district_name = input("Enter District Name: ")

prediction = predict_crop(N, P, K, pH, season, district_name)
print("Predicted Crop:", prediction)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter Nitrogen (N) value: 90
# Enter Phosphorus (P) value: 84
# Enter Potassium (K) value: 75
# Enter pH value: 6.35
# Enter Season (kharif, rabi): Rabi
# Enter District Name: SIKAR
# Predicted Crop: coconut

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/model1 (1).csv'
df = pd.read_csv(file_path)

numerical_cols = df.select_dtypes(include=['number']).columns

correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

numeric_data = df.select_dtypes(include=['number'])
sns.pairplot(numeric_data, kind="scatter", diag_kind="kde")
plt.suptitle("Scatter and Density Plots for model1 (1)", y=1.02) # Added title
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive


drive.mount('/content/drive')
file_path = '/content/drive/My Drive/model1 (1).csv'
df = pd.read_csv(file_path)

# !pip install shap

import shap

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = df['Crop']

le = LabelEncoder()

y_encoded = le.fit_transform(y)


model = LinearRegression()
model.fit(X, y_encoded)

explainer = shap.Explainer(model, X)
shap_values = explainer(X)

shap.plots.beeswarm(shap_values)

shap.dependence_plot("N", shap_values.values, X, interaction_index="P")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = df['Crop']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gb_model.fit(X_train, y_train)

y_pred = gb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Gradient Boosting Classifier Accuracy: {accuracy}")
# Out:
# Gradient Boosting Classifier Accuracy: 0.9999199807953909

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = df['Crop']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Decision Tree Classifier Accuracy: {accuracy}")
# Out:
# Decision Tree Classifier Accuracy: 0.9999199807953909

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = df['Crop']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Random Forest Classifier Accuracy: {accuracy}")
# Out:
# Random Forest Classifier Accuracy: 0.9999199807953909

# %%
import pandas as pd
import matplotlib.pyplot as plt

r2_scores = {
    'XAI-CROP': [0.8, 0.85, 0.9, 0.92, 0.93],
    'Gradient Boosting': [0.75, 0.8, 0.88, 0.9, 0.91],
    'Decision Tree': [0.7, 0.78, 0.85, 0.87, 0.89],
    'Random Forest': [0.82, 0.87, 0.91, 0.93, 0.94]
}

epochs = range(1, len(r2_scores['XAI-CROP']) + 1)

plt.figure(figsize=(10, 6))

for model, scores in r2_scores.items():
    plt.plot(epochs, scores, label=model)

plt.xlabel('Epoch')
plt.ylabel('R^2 Score')
plt.title('R^2 Convergence Curve')
plt.legend()
plt.grid(True)
plt.show()
